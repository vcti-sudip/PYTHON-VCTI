# %%
student = {}

name = input("Enter name: ")
marks = float(input("Enter percentage: "))

student[name] = marks

print("Student Details:")
print(student)
# Out:
# Student Details:
# {'Sudip': 85.0}

# %%
text = input("Enter a string: ")

count = {}

for ch in text:
    if ch != " ":
        count[ch] = count.get(ch, 0) + 1

print(count)
# Out:
# {'S': 1, 'u': 1, 'd': 1, 'i': 1, 'p': 1, '1': 1, '2': 1, '3': 1}

# %%
text = input("Enter a string: ").lower()

vowels = {'a': 0, 'e': 0, 'i': 0, 'o': 0, 'u': 0}

for ch in text:
    if ch in vowels:
        vowels[ch] += 1

print(vowels)
# Out:
# {'a': 1, 'e': 1, 'i': 1, 'o': 1, 'u': 1}

# %%
student = {}

n = int(input("Enter number of students: "))

for i in range(n):
    name = input("Enter name: ")
    marks = float(input("Enter marks: "))
    student[name] = marks

search = input("Enter student name to search: ")

if search in student:
    print("Marks:", student[search])
else:
    print("Student not found")
# Out:
# Marks: 98.0

# %%
print(f"{'Property':<22}{'List':<10}{'Tuple':<10}{'Set':<10}{'Frozenset':<12}{'Dictionary'}")

print(f"{'Syntax':<22}[]        ()        {{}}        frozenset()  {{key:value}}")
print(f"{'Ordered':<22}Yes       Yes       No        No          Yes")
print(f"{'Mutable':<22}Yes       No        Yes       No          Yes")
print(f"{'Allow Duplicates':<22}Yes       Yes       No        No          Keys-No")
print(f"{'Indexed':<22}Yes       Yes       No        No          By Key")
print(f"{'Heterogeneous':<22}Yes       Yes       Yes       Yes         Yes")
print(f"{'Hashable':<22}No        Yes       No        Yes         No")
print(f"{'Dictionary Key':<22}No        Yes       No        Yes         N/A")
print(f"{'Can be Nested':<22}Yes       Yes       Yes       Yes         Yes")
print(f"{'Supports Slicing':<22}Yes       Yes       No        No          No")
print(f"{'Lookup Speed':<22}Slow      Slow      Fast      Fast        Fast")
print(f"{'Stores':<22}Values    Values    Unique    Unique      Key-Value")
print(f"{'Typical Use':<22}Sequence Fixed     Unique    Immutable   Mapping")
# Out:
# Property              List      Tuple     Set       Frozenset   Dictionary
# Syntax                []        ()        {}        frozenset()  {key:value}
# Ordered               Yes       Yes       No        No          Yes
# Mutable               Yes       No        Yes       No          Yes
# Allow Duplicates      Yes       Yes       No        No          Keys-No
# Indexed               Yes       Yes       No        No          By Key
# Heterogeneous         Yes       Yes       Yes       Yes         Yes
# Hashable              No        Yes       No        Yes         No
# Dictionary Key        No        Yes       No        Yes         N/A
# Can be Nested         Yes       Yes       Yes       Yes         Yes
# Supports Slicing      Yes       Yes       No        No          No
# Lookup Speed          Slow      Slow      Fast      Fast        Fast
# Stores                Values    Values    Unique    Unique      Key-Value
# ...
